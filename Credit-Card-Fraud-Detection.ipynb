# %% [markdown]
# ## Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,f1_score,precision_score,recall_score
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_curve,roc_auc_score
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv('C:/Users/Rupesh/Downloads/archive (22)/creditcard.csv')
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Checking for Shape
df.shape
# Out:
# (284807, 31)

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Statistical Summary
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
# Checking for imbalanced data
df['Class' ].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# * The dataset is highly imbalanced

# %%
# one hot encoding
df= pd.get_dummies(data=df,drop_first=True)

# %% [markdown]
# ## Countplot

# %%
sns.countplot(df['Class'])
plt.plot
# Out:
# C:\Users\Rupesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %% [markdown]
# ## Correlation matrix and heatmap

# %%
df_1 = df.drop(columns=['Class'])
df_1.corrwith(df['Class']).plot.bar(figsize=(16,9),title='Correlated with Class',rot=45,grid=True)
# Out:
# <AxesSubplot:title={'center':'Correlated with Class'}>

# %%
corr = df.corr()
plt.figure(figsize=(40,20))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Splitting the Dataset

# %%
# matrix of features
x= df.drop(columns='Class')
# dependent variable
y = df['Class']

# %%
# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(
     x, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## StandardScaler

# %%
sc = StandardScaler()
x_train = sc.fit_transform(X_train)
x_test  = sc.transform(X_test)

# %% [markdown]
# ## Logistic Regression

# %%
classifier_lr = LogisticRegression()
classifier_lr.fit(x_train,y_train)
y_pred = classifier_lr.predict(x_test)
acc = accuracy_score(y_test,y_pred)
f1  = f1_score(y_test,y_pred)
prec = precision_score(y_test,y_pred)
rec = recall_score(y_test,y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
results = pd.DataFrame([['Logistic Regression',acc,f1,prec,rec,roc_auc]],
                      columns=['Model','Accuracy','F1','precision','Recall','ROC-AUC-Score'])
results
# Out:
#                  Model  Accuracy        F1  precision    Recall  ROC-AUC-Score
# 0  Logistic Regression  0.999192  0.735632   0.876712  0.633663       0.816753

# %% [markdown]
# ## Random Forest Classifier

# %%
classifier_rf = RandomForestClassifier(random_state=0)
classifier_rf.fit(x_train,y_train)
y_pred = classifier_rf.predict(x_test)
acc = accuracy_score(y_test,y_pred)
f1  = f1_score(y_test,y_pred)
prec = precision_score(y_test,y_pred)
rec = recall_score(y_test,y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
results_1 = pd.DataFrame([['Random Forest',acc,f1,prec,rec,roc_auc]],
                      columns=['Model','Accuracy','F1','precision','Recall','ROC-AUC-Score'])
agg_result = results.append(results_1,ignore_index=True)
agg_result
# Out:
# C:\Users\Rupesh\AppData\Local\Temp\ipykernel_2524\2844168780.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_result = results.append(results_1,ignore_index=True)
#                  Model  Accuracy        F1  precision    Recall  ROC-AUC-Score
# 0  Logistic Regression  0.999192  0.735632   0.876712  0.633663       0.816753
# 1        Random Forest  0.999491  0.844920   0.918605  0.782178       0.891028

# %% [markdown]
# ## XG Boost Classifier

# %%
classifier_xgb = XGBClassifier(random_state=0)
classifier_xgb.fit(x_train,y_train)
y_pred = classifier_xgb.predict(x_test)
acc = accuracy_score(y_test,y_pred)
f1  = f1_score(y_test,y_pred)
prec = precision_score(y_test,y_pred)
rec = recall_score(y_test,y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
results_2 = pd.DataFrame([['XG boost',acc,f1,prec,rec,roc_auc]],
                      columns=['Model','Accuracy','F1','precision','Recall','ROC-AUC-Score'])
agg_result.append(results_2,ignore_index=True)
# Out:
# C:\Users\Rupesh\AppData\Local\Temp\ipykernel_2524\2246953522.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   agg_result.append(results_2,ignore_index=True)
#                  Model  Accuracy        F1  precision    Recall  ROC-AUC-Score
# 0  Logistic Regression  0.999192  0.735632   0.876712  0.633663       0.816753
# 1        Random Forest  0.999491  0.844920   0.918605  0.782178       0.891028
# 2             XG boost  0.999614  0.884211   0.943820  0.831683       0.915798

# %% [markdown]
# ## Dealing with Imbalanced Data

# %%
smote = SMOTE(random_state=0)
x_train_resampled,y_train_resampled = smote.fit_resample(x_train,y_train)

# %% [markdown]
#  (XG_Boost_With_Smote_Oversampling)

# %%
xgb_classifier_1 = XGBClassifier(random_state=0)
xgb_classifier_1.fit(x_train_resampled, y_train_resampled)
y_pred = xgb_classifier_1.predict(X_test)
roc_auc = roc_auc_score(y_test, y_pred)

acc = accuracy_score(y_test,y_pred)
f1  = f1_score(y_test,y_pred)
prec = precision_score(y_test,y_pred)
rec = recall_score(y_test,y_pred)
results_2 = pd.DataFrame([['XG boost',acc,f1,prec,rec,roc_auc]],
                      columns=['Model','Accuracy','F1','precision','Recall','ROC-AUC-Score'])

results_2
# Out:
#       Model  Accuracy        F1  precision    Recall  ROC-AUC-Score
# 0  XG boost  0.999403  0.833333   0.825243  0.841584       0.920634

# %% [markdown]
# * XG Boost without Resampling is giving best results
